# %%
#import dependencies
import pandas as pd

# %%
#create csv path
stats = "InvoiceStats.csv"

# Read the CSV into a Pandas DataFrame
inv_stats = pd.read_csv(stats)

inv_stats.head()
# Out:
#   Billing Group Invoice Status  Servicing Dealer Dealer Invoice  \
# 0            HD   Raymond Paid             60791      V30096632
# 1            AZ   Raymond Paid             60791      V30096663
# 2            HD   Raymond Paid             60791      V30096723
# 3            HD   Raymond Paid             60791      V30096630
# 4            HD   Raymond Paid             60791      V30096631
#
#    Requested Amount  Approved Amount Invoice Create Date Invoice Issue?
# 0             85.00            85.00          01-05-2021            Yes
# 1            120.00           120.00          01-05-2021             No
# 2            135.13           135.13          01-05-2021             No
# 3            159.13           159.13          01-05-2021             No
# 4            195.23           195.23          01-05-2021             No

# %%
#Reorganize columns and drop unnecessary columns

inv_stats = inv_stats[["Servicing Dealer", "Billing Group", "Dealer Invoice", "Invoice Status", "Approved Amount", "Invoice Create Date", "Invoice Issue?"]]

inv_stats.head()
# Out:
#    Servicing Dealer Billing Group Dealer Invoice Invoice Status  \
# 0             60791            HD      V30096632   Raymond Paid
# 1             60791            AZ      V30096663   Raymond Paid
# 2             60791            HD      V30096723   Raymond Paid
# 3             60791            HD      V30096630   Raymond Paid
# 4             60791            HD      V30096631   Raymond Paid
#
#    Approved Amount Invoice Create Date Invoice Issue?
# 0            85.00          01-05-2021            Yes
# 1           120.00          01-05-2021             No
# 2           135.13          01-05-2021             No
# 3           159.13          01-05-2021             No
# 4           195.23          01-05-2021             No

# %%
#rename columns

inv_stats = inv_stats.rename(columns={"Servicing Dealer":"Branch", "Billing Group":"Customer", "Dealer Invoice":"Inv_Number", "Invoice Status":"Inv_Status", "Approved Amount":"App_Amt", "Invoice Create Date":"Inv_Date", "Invoice Issue?":"Inv_Issue"})


inv_stats.head()
# Out:
#    Branch Customer Inv_Number    Inv_Status  App_Amt    Inv_Date Inv_Issue
# 0   60791       HD  V30096632  Raymond Paid    85.00  01-05-2021       Yes
# 1   60791       AZ  V30096663  Raymond Paid   120.00  01-05-2021        No
# 2   60791       HD  V30096723  Raymond Paid   135.13  01-05-2021        No
# 3   60791       HD  V30096630  Raymond Paid   159.13  01-05-2021        No
# 4   60791       HD  V30096631  Raymond Paid   195.23  01-05-2021        No

# %%
inv_stats.dtypes
# Out:
# Branch          int64
# Customer       object
# Inv_Number     object
# Inv_Status     object
# App_Amt       float64
# Inv_Date       object
# Inv_Issue      object
# dtype: object

# %%
#update Inv Date to datetime
inv_stats["Inv_Date"] = pd.to_datetime(inv_stats["Inv_Date"])

# %%
#rename branch number to abbreviation
inv_stats = inv_stats.replace({60789:"DEN", 60790:"DEN", 60791:"SLC", 60792:"ABQ"})

inv_stats.head()
# Out:
#   Branch Customer Inv_Number    Inv_Status  App_Amt   Inv_Date Inv_Issue
# 0    SLC       HD  V30096632  Raymond Paid    85.00 2021-01-05       Yes
# 1    SLC       AZ  V30096663  Raymond Paid   120.00 2021-01-05        No
# 2    SLC       HD  V30096723  Raymond Paid   135.13 2021-01-05        No
# 3    SLC       HD  V30096630  Raymond Paid   159.13 2021-01-05        No
# 4    SLC       HD  V30096631  Raymond Paid   195.23 2021-01-05        No

# %%
#view customer values so abbreviations can be updated to customer name
inv_stats["Customer"].value_counts()
# Out:
#  AZ     1473
#  WM      844
#  HD      772
#  ML      351
#  UA      210
#  KH      181
#  XPO     159
#  HS      158
#  ITL     150
#  SC      140
#  ARM     125
#  KN      103
#  WW       67
#  TCI      63
#  BZ       52
#  MR       38
#  MFD      36
#  CO       36
#  XL       32
#  TSI      29
#  HF       29
#  OD       27
#  PCS      24
#  HDD      23
#  AR       23
#  BKR      22
#  WAY      22
#  COL      21
#  GS       12
#  LME       8
#  BL        3
#  PTN       2
# Name: Customer, dtype: int64

# %%
#updated customer abbreviations
inv_stats = inv_stats.replace({" AZ":"Amazon", " HD":"Home Depot", " WM":"Walmart", " ML":"Medline", " UA":"US Autoforce",
                                                " KH":"KeHE", " ITL":"HD Pro", " HS":"HD Supply", " XPO":"GXO Logistics", " SC":"Sam's Club", " ARM": "Aramsco",
                                                " KN": "Kuehne + Nagel", " WW":"Grainger", " TCI":"TBC International", " XL":"DHL", " BZ":"Bunzl",
                                                " TSI":"Sealy Mattress", " MR":"Lineage Logistics", " MFD":"Mattress Firm", " OD":"Office Depot", " CO":"Costco",
                                                " AR":"Americold", " HF":"Harbor Freight", " HDD":"HD Pro", " PCS":"Petco", " BKR":"Baker Dist", " COL":"Composites One", " WAY":"Wayfair", 
                                                " GS":"Gensco", " BL":"Big Lots", " PTN":"Peloton", " LME":"XPO Last Mile", " BBB": "Bed Bath Beyond"})

inv_stats.head()
# Out:
#   Branch    Customer Inv_Number    Inv_Status  App_Amt   Inv_Date Inv_Issue
# 0    SLC  Home Depot  V30096632  Raymond Paid    85.00 2021-01-05       Yes
# 1    SLC      Amazon  V30096663  Raymond Paid   120.00 2021-01-05        No
# 2    SLC  Home Depot  V30096723  Raymond Paid   135.13 2021-01-05        No
# 3    SLC  Home Depot  V30096630  Raymond Paid   159.13 2021-01-05        No
# 4    SLC  Home Depot  V30096631  Raymond Paid   195.23 2021-01-05        No

# %%
#verify all customer names updated
inv_stats["Customer"].value_counts()
# Out:
# Amazon               1473
# Walmart               844
# Home Depot            772
# Medline               351
# US Autoforce          210
# KeHE                  181
# HD Pro                173
# GXO Logistics         159
# HD Supply             158
# Sam's Club            140
# Aramsco               125
# Kuehne + Nagel        103
# Grainger               67
# TBC International      63
# Bunzl                  52
# Lineage Logistics      38
# Costco                 36
# Mattress Firm          36
# DHL                    32
# Sealy Mattress         29
# Harbor Freight         29
# Office Depot           27
# Petco                  24
# Americold              23
# Baker Dist             22
# Wayfair                22
# Composites One         21
# Gensco                 12
# XPO Last Mile           8
# Big Lots                3
# Peloton                 2
# Name: Customer, dtype: int64

# %%
#create new column for month 
inv_stats["Month"] = inv_stats["Inv_Date"].dt.month
inv_stats.head()
# Out:
#   Branch    Customer Inv_Number    Inv_Status  App_Amt   Inv_Date Inv_Issue  \
# 0    SLC  Home Depot  V30096632  Raymond Paid    85.00 2021-01-05       Yes
# 1    SLC      Amazon  V30096663  Raymond Paid   120.00 2021-01-05        No
# 2    SLC  Home Depot  V30096723  Raymond Paid   135.13 2021-01-05        No
# 3    SLC  Home Depot  V30096630  Raymond Paid   159.13 2021-01-05        No
# 4    SLC  Home Depot  V30096631  Raymond Paid   195.23 2021-01-05        No
#
#    Month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
#replace Month number with name

inv_stats["Month"] = inv_stats["Month"].replace({1:"January", 2:"February", 3:"March", 4:"April", 5:"May", 6:"June", 
                                                         7:"July", 8:"August", 9:"September", 10:"October", 11:"November", 
                                                         12:"December"})

# %%
#verify all values have updated
inv_stats["Month"].value_counts()
# Out:
# September    597
# October      535
# February     500
# January      490
# March        488
# April        488
# July         451
# June         441
# August       433
# November     371
# May          290
# December     151
# Name: Month, dtype: int64

# %%
#create new dataframe with summary of total number of invoices, invoices with and without errors and percentage per branch

#branch total invoices
branch_total = inv_stats["Branch"].value_counts()

#branch inv count with errors
#filter main DF to only show "Yes" in Inv_Issue column
stats = inv_stats[inv_stats.Inv_Issue == "Yes"]
#count of invoices with issues per branch
issue = stats.groupby(["Branch"]).count()["Inv_Issue"]

#subtract inv issues from total to calculate no issues
no_issue = branch_total - issue

#calculate percentage with error
percent = issue/branch_total *100

# %%
#new DF
stat_summary = pd.DataFrame({"Total_Inv": branch_total, "Issue": issue, "No_Issue":no_issue, "Issue_Percent":percent})

stat_summary
# Out:
#      Total_Inv  Issue  No_Issue  Issue_Percent
# ABQ        176     97        79      55.113636
# DEN       2962    916      2046      30.925051
# SLC       2097   1150       947      54.840248

# %%
#caculate totals for each column

#total invoices
summary_total = stat_summary["Total_Inv"].sum()

#total invoices with issues
issue_total = stat_summary["Issue"].sum()

#total invoices without issues
no_issue_total = stat_summary["No_Issue"].sum()

#percentage with error
percent_total = issue_total/summary_total *100

#create new DF to merge with stat_summary
total_summary = pd.DataFrame({"Total_Inv": [summary_total], "Issue":[issue_total], "No_Issue":[no_issue_total], "Issue_Percent":[percent_total]})
total_summary.round({"Issue_Percent":2})
# Out:
#    Total_Inv  Issue  No_Issue  Issue_Percent
# 0       5235   2163      3072      41.318052

# %%
#merge both summary DFs
summary = stat_summary.append(total_summary)

summary.round({"Issue_Percent":2})

summary
# Out:
#      Total_Inv  Issue  No_Issue  Issue_Percent
# ABQ        176     97        79      55.113636
# DEN       2962    916      2046      30.925051
# SLC       2097   1150       947      54.840248
# 0         5235   2163      3072      41.318052

# %%
#rename index 0 to Total
clean_summary=summary.rename({0: "Total"})

#rename axis to Branch
branch_stat_summary = clean_summary.rename_axis("Branch")

branch_stat_summary
# Out:
#         Total_Inv  Issue  No_Issue  Issue_Percent
# Branch
# ABQ           176     97        79      55.113636
# DEN          2962    916      2046      30.925051
# SLC          2097   1150       947      54.840248
# Total        5235   2163      3072      41.318052

# %%
#reformat issue percent

branch_stat_summary.style.format({'Issue_Percent':'${:.2f}'})
branch_stat_summary
# Out:
#         Total_Inv  Issue  No_Issue  Issue_Percent
# Branch
# ABQ           176     97        79      55.113636
# DEN          2962    916      2046      30.925051
# SLC          2097   1150       947      54.840248
# Total        5235   2163      3072      41.318052

# %%
#create summary csv
branch_stat_summary.to_csv("CleanData/StatSummary.csv")
